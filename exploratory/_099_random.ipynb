# %% [markdown]
# # 1. Import Libraries

# %%
import os
import pandas as pd

# %% [markdown]
# # 2. Call Dataset

# %%
df = pd.read_csv(r"/Users/i.putra/Documents/BinaryClassProject/dataset/raw/dummy_dataset.csv")
display(df)
# Out:
#        is_churn  customer_id partition_date  feature_a  feature_b  feature_c  \
# 0             1            1     2025-01-01  -0.589447  -0.959914  -1.343678
# 1             0            2     2025-01-01   0.412484   0.887396  -0.121051
# 2             0            3     2025-01-01  -1.165200   1.151621  -1.096162
# 3             0            4     2025-01-01  -1.600626   0.278260   1.305405
# 4             1            5     2025-01-01   0.781079   0.599033  -0.794560
# ...         ...          ...            ...        ...        ...        ...
# 14995         0        14996     2025-03-31   0.893051   0.601143   2.059850
# 14996         1        14997     2025-03-31   0.452609   0.279572  -0.150313
# 14997         0        14998     2025-03-31   0.239228  -3.196903  -0.723379
# 14998         0        14999     2025-03-31   1.382330  -1.041489  -2.448949
# 14999         0        15000     2025-03-31   1.130939   1.137092  -1.297270
#
# ...
